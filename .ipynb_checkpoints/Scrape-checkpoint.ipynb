# %%
# Import required modules
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url = 'http://timing.rev3tri.com/mobile/athlete-results/D5520FB7-20E3-407B-9A11-A666E43BA256/2/1235'

# %%
url = 'http://timing.rev3tri.com/mobile/athlete-results/D5520FB7-20E3-407B-9A11-A666E43BA256/2/1235'
def parse_racer_page( url ):
    "Given a Rev3 results page, scrape variables into a dictionary"
    r = requests.get(url)
    # Turn the HTML into a Beautiful Soup object
    soup = BeautifulSoup(r.text, 'lxml') 
    #get variables
    racer={}
    racer['name']=soup.find_all('h2')[1].string.strip()
    #overview table
    table=soup.find_all('table')[0]
    rows=table.find_all('tr')
    racer['bib']=int(rows[0].find_all('td')[1].string.strip())
    racer['division']=rows[1].find_all('td')[1].string.strip()
    racer['gender']=rows[2].find_all('td')[1].string.strip()
    racer['total_time']=rows[4].find_all('td')[1].string.strip().split(".")[0]
    #overview table
    table=soup.find_all('table')[1]
    rows=table.find_all('tr')[1:]
    racer['swim_time']=rows[0].find_all('td')[1].string.strip()
    racer['swim_pace']=rows[0].find_all('td')[2].string.strip()
    racer['bike_time']=rows[1].find_all('td')[1].string.strip()
    racer['bike_pace']=float(rows[1].find_all('td')[2].string.strip().split(" ")[0])
    racer['run_time']=rows[2].find_all('td')[1].string.strip()
    racer['run_pace']=rows[2].find_all('td')[2].string.strip()
    #split table
    table=soup.find_all('table')[2]
    rows=table.find_all('tr')[1:]
    racer['division']=rows[0].find_all('td')[0].string.strip()
    racer['swim_pace']=rows[1].find_all('td')[3].string.strip()
    racer['swim_r_division']=rows[1].find_all('td')[4].string.strip()
    racer['swim_r_gender']=rows[1].find_all('td')[5].string.strip()
    racer['swim_r_overall']=rows[1].find_all('td')[6].string.strip()
    racer['t1_time']=rows[2].find_all('td')[2].string.strip()
    racer['bike_sA31_time']=rows[4].find_all('td')[2].string.strip()
    racer['bike_sA31_speed']=rows[4].find_all('td')[3].string.strip()
    racer['bike_sA31_r_division']=rows[4].find_all('td')[4].string.strip()
    racer['bike_sA31_r_gender']=rows[4].find_all('td')[5].string.strip()
    racer['bike_sA31_r_overall']=rows[4].find_all('td')[6].string.strip()
    racer['bike_sB25_time']=rows[5].find_all('td')[2].string.strip()
    racer['bike_sB25_speed']=rows[5].find_all('td')[3].string.strip()
    racer['bike_sB25_r_division']=rows[5].find_all('td')[4].string.strip()
    racer['bike_sB25_r_gender']=rows[5].find_all('td')[5].string.strip()
    racer['bike_sB25_r_overall']=rows[5].find_all('td')[6].string.strip()
    racer['t2_time']=rows[6].find_all('td')[2].string.strip()
    racer['run_sA2.75_time']=rows[8].find_all('td')[2].string.strip()
    racer['run_sA2.75_speed']=rows[8].find_all('td')[3].string.strip()
    racer['run_sA2.75_r_division']=rows[8].find_all('td')[4].string.strip()
    racer['run_sA2.75_r_gender']=rows[8].find_all('td')[5].string.strip()
    racer['run_sA2.75_r_overall']=rows[8].find_all('td')[6].string.strip()
    racer['run_sB9.05_time']=rows[9].find_all('td')[2].string.strip()
    racer['run_sB9.05_speed']=rows[9].find_all('td')[3].string.strip()
    racer['run_sB9.05_r_division']=rows[9].find_all('td')[4].string.strip()
    racer['run_sB9.05_r_gender']=rows[9].find_all('td')[5].string.strip()
    racer['run_sB9.05_r_overall']=rows[9].find_all('td')[6].string.strip()
    racer['run_sC4.05_time']=rows[10].find_all('td')[2].string.strip()
    racer['run_sC4.05_speed']=rows[10].find_all('td')[3].string.strip()
    racer['run_sC4.05_r_division']=rows[10].find_all('td')[4].string.strip()
    racer['run_sC4.05_r_gender']=rows[10].find_all('td')[5].string.strip()
    racer['run_sC4.05_r_overall']=rows[10].find_all('td')[6].string.strip()
    return racer
parse_racer_page(url)
# Out:
# {'bib': 21,
#  'bike_pace': 19.2,
#  'bike_sA31_r_division': '30 / 44',
#  'bike_sA31_r_gender': '130 / 201',
#  'bike_sA31_r_overall': '182 / 315',
#  'bike_sA31_speed': '18.84 mph',
#  'bike_sA31_time': '1:38:44',
#  'bike_sB25_r_division': '31 / 44',
#  'bike_sB25_r_gender': '130 / 201',
#  'bike_sB25_r_overall': '176 / 315',
#  'bike_sB25_speed': '19.67 mph',
#  'bike_sB25_time': '1:16:15',
#  'bike_time': '02:54:59.003',
#  'division': 'Wave 1 - Men 39 & Under, Clydesdale / Chip time: 6:45:00 AM',
#  'gender': 'M',
#  'name': 'Bruno Sanchez-Andrade Nuño',
#  'run_pace': '12:19 /mi',
#  'run_sA2.75_r_division': '13 / 44',
#  'run_sA2.75_r_gender': '51 / 201',
#  'run_sA2.75_r_overall': '59 / 315',
#  'run_sA2.75_speed': '00:00 /mi',
#  'run_sA2.75_time': '15:58',
#  'run_sB9.05_r_division': '16 / 44',
#  'run_sB9.05_r_gender': '61 / 201',
#  'run_sB9.05_r_overall': '73 / 315',
#  'run_sB9.05_speed': '04:09 /mi',
#  'run_sB9.05_time': '37:34',
# ...

# %%
url='http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2'
domain="http://timing.rev3tri.com"

#collect urls of racers
"Given a Rev3 results page, scrape variables into a dictionary"
racers_urls=[]
for page in np.arange(1,16):
    r = requests.get(url+'/'+str(page))
    soup = BeautifulSoup(r.text, 'lxml') 
    print(url+'/'+str(page),'-',len(soup.find_all('table')[1].find_all("a")))
    for link in soup.find_all('table')[1].find_all("a")[4:]:
        racers_urls.append(domain+link.get("href"))
racers_urls
# Out:
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/1 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/2 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/3 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/4 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/5 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/6 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/7 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/8 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/9 - 29
# http://timing.rev3tri.com/mobile/athlete-search/D5520FB7-20E3-407B-9A11-A666E43BA256/2/10 - 29
# ...

# %%
runner={}
for url in racers_urls:
    try:
        racer=parse_racer_page( url )
        racer['error']=''
    except:
        pass
        racer['error']='yes'
    runner[racer['bib']]=racer
    print(racer['bib'],racer['error'])
# Out:
# 314
# 548
# 305
# 227
# 343
# 241
# 241 yes
# 389
# 389 yes
# 236
# 381
# 335
# 328
# 304
# 387
# 237
# 326
# 575
# 278
# 378
# 329
# 436
# 323
# 520
# 204
# 566
# 566 yes
# 537
# 306
# 279
# 281
# 28
# 277
# 574
# 318
# 569
# 50
# 536
# 516
# 226
# 538
# 443
# 116
# 324
# 437
# 231
# 442
# 526
# 295
# 523
# 321
# 346
# 362
# 491
# 446
# 245
# 23
# 354
# 540
# 445
# 31
# 298
# 555
# 370
# 360
# 419
# 398
# 319
# 582
# 209
# 24
# 32
# 348
# 474
# 567
# 418
# 579
# 303
# 527
# 521
# 332
# 388
# 123
# 123 yes
# 117
# 345
# 518
# 522
# 377
# 172
# 525
# 456
# 316
# 132
# 543
# 238
# 564
# 554
# 365
# 208
# 395
# 80
# 454
# 511
# 552
# 358
# 274
# 302
# 431
# 161
# 210
# 433
# 383
# 532
# 37
# 434
# 463
# 366
# 288
# 310
# 577
# 207
# 541
# 546
# 514
# 364
# 173
# 587
# 556
# 386
# 513
# 457
# 588
# 297
# 119
# 337
# 471
# 390
# 524
# 396
# 550
# 320
# 291
# 317
# 519
# 533
# 283
# 206
# 571
# 384
# 290
# 542
# 322
# 512
# 349
# 553
# 455
# 484
# 39
# 312
# 164
# 410
# 114
# 576
# 429
# ...

# %%
df = pd.DataFrame(runner).transpose()

# %%
df
# Out:
#      bib  bike_pace bike_sA31_r_division bike_sA31_r_gender  \
# 20    20  16.97 mph              22 / 25          172 / 201
# 21    21  19.20 mph              30 / 44          130 / 201
# 23    23  20.98 mph               2 / 18            9 / 114
# 24    24  19.79 mph                2 / 7           66 / 201
# 25    25  17.97 mph              15 / 25          122 / 201
# 26    26  18.26 mph              23 / 25          176 / 201
# 28    28  21.95 mph              15 / 44           54 / 201
# 29    29  19.21 mph              15 / 29          108 / 201
# 30    30  17.70 mph              21 / 26          150 / 201
# 31    31  22.25 mph               5 / 26           44 / 201
# 32    32  21.48 mph               4 / 22           51 / 201
# 33    33  17.41 mph              10 / 13          168 / 201
# 37    37  19.15 mph                1 / 6           15 / 114
# 39    39  19.83 mph               9 / 23           36 / 114
# 41    41  16.44 mph              10 / 17           82 / 114
# ...

# %%
df.to_csv('Rev3Half-times.csv')
